# %% [markdown]
# <a href="https://colab.research.google.com/github/seunghee-lee/Portfolio/blob/main/Data_Analysis_with_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### pandas 기초

# %%
import pandas as pd

# %%
df = pd.DataFrame([10, 20, 30, 40],
                  columns=['numbers'],
                  index=['a', 'b', 'c', 'd'])
df
# Out:
#    numbers
# a       10
# b       20
# c       30
# d       40

# %%
df.index
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %%
df.columns
# Out:
# Index(['numbers'], dtype='object')

# %%
df.loc['c']
# Out:
# numbers    30
# Name: c, dtype: int64

# %%
df.loc[['a', 'd']]  # 여러 개의 인덱스를 사용한 선택
# Out:
#    numbers
# a       10
# d       40

# %%
df.iloc[1:3]  # index 객체를 사용한 선택
# Out:
#    numbers
# b       20
# c       30

# %%
df.sum()  # 열의 합
# Out:
# numbers    100
# dtype: int64

# %%
df.apply(lambda x: x ** 2)  # lambda 함수를 사용하여 각 원소의 제곱
# Out:
#    numbers
# a      100
# b      400
# c      900
# d     1600

# %%
df ** 2
# Out:
#    numbers
# a      100
# b      400
# c      900
# d     1600

# %%
df['floats'] = (1.5, 2.5, 3.5, 4.5)  # 새 열을 생성
df
# Out:
#    numbers  floats
# a       10     1.5
# b       20     2.5
# c       30     3.5
# d       40     4.5

# %%
df['floats']  # 열 선택
# Out:
# a    1.5
# b    2.5
# c    3.5
# d    4.5
# Name: floats, dtype: float64

# %%
df['names'] = pd.DataFrame(['Yves', 'Sandra', 'Lilli', 'Henry'],
                           index=['d', 'a', 'b', 'c'])
df
# Out:
#    numbers  floats   names
# a       10     1.5  Sandra
# b       20     2.5   Lilli
# c       30     3.5   Henry
# d       40     4.5    Yves

# %% [markdown]
# ### DataFrame Class 다루기 2단계

# %%
import numpy as np
np.random.seed(100)

# %%
a = np.random.standard_normal((9, 4))
a
# Out:
# array([[-1.74976547,  0.3426804 ,  1.1530358 , -0.25243604],
#        [ 0.98132079,  0.51421884,  0.22117967, -1.07004333],
#        [-0.18949583,  0.25500144, -0.45802699,  0.43516349],
#        [-0.58359505,  0.81684707,  0.67272081, -0.10441114],
#        [-0.53128038,  1.02973269, -0.43813562, -1.11831825],
#        [ 1.61898166,  1.54160517, -0.25187914, -0.84243574],
#        [ 0.18451869,  0.9370822 ,  0.73100034,  1.36155613],
#        [-0.32623806,  0.05567601,  0.22239961, -1.443217  ],
#        [-0.75635231,  0.81645401,  0.75044476, -0.45594693]])

# %%
df = pd.DataFrame(a)
df
# Out:
#           0         1         2         3
# 0 -1.749765  0.342680  1.153036 -0.252436
# 1  0.981321  0.514219  0.221180 -1.070043
# 2 -0.189496  0.255001 -0.458027  0.435163
# 3 -0.583595  0.816847  0.672721 -0.104411
# 4 -0.531280  1.029733 -0.438136 -1.118318
# 5  1.618982  1.541605 -0.251879 -0.842436
# 6  0.184519  0.937082  0.731000  1.361556
# 7 -0.326238  0.055676  0.222400 -1.443217
# 8 -0.756352  0.816454  0.750445 -0.455947

# %%
df.columns = ['No1', 'No2', 'No3', 'No4']  # 열 이름 지정
df
# Out:
#         No1       No2       No3       No4
# 0 -1.749765  0.342680  1.153036 -0.252436
# 1  0.981321  0.514219  0.221180 -1.070043
# 2 -0.189496  0.255001 -0.458027  0.435163
# 3 -0.583595  0.816847  0.672721 -0.104411
# 4 -0.531280  1.029733 -0.438136 -1.118318
# 5  1.618982  1.541605 -0.251879 -0.842436
# 6  0.184519  0.937082  0.731000  1.361556
# 7 -0.326238  0.055676  0.222400 -1.443217
# 8 -0.756352  0.816454  0.750445 -0.455947

# %%
df['No2'][3]  # No2 열의 3번 인덱스 위치 자료
# Out:
# np.float64(0.816847071685779)

# %%
df['No2'].mean()  # No2 열의 평균
# Out:
# np.float64(0.7010330941456459)

# %%
dates = pd.date_range('2024-9-1', periods=9, freq='ME')
dates
# Out:
# DatetimeIndex(['2024-09-30', '2024-10-31', '2024-11-30', '2024-12-31',
#                '2025-01-31', '2025-02-28', '2025-03-31', '2025-04-30',
#                '2025-05-31'],
#               dtype='datetime64[ns]', freq='ME')

# %%
df.index = dates   # DatetimeIndex로 DataFrame 인덱스 명칭 변경
df
# Out:
#                  No1       No2       No3       No4
# 2024-09-30 -1.749765  0.342680  1.153036 -0.252436
# 2024-10-31  0.981321  0.514219  0.221180 -1.070043
# 2024-11-30 -0.189496  0.255001 -0.458027  0.435163
# 2024-12-31 -0.583595  0.816847  0.672721 -0.104411
# 2025-01-31 -0.531280  1.029733 -0.438136 -1.118318
# 2025-02-28  1.618982  1.541605 -0.251879 -0.842436
# 2025-03-31  0.184519  0.937082  0.731000  1.361556
# 2025-04-30 -0.326238  0.055676  0.222400 -1.443217
# 2025-05-31 -0.756352  0.816454  0.750445 -0.455947

# %%
df.values
# Out:
# array([[-1.74976547,  0.3426804 ,  1.1530358 , -0.25243604],
#        [ 0.98132079,  0.51421884,  0.22117967, -1.07004333],
#        [-0.18949583,  0.25500144, -0.45802699,  0.43516349],
#        [-0.58359505,  0.81684707,  0.67272081, -0.10441114],
#        [-0.53128038,  1.02973269, -0.43813562, -1.11831825],
#        [ 1.61898166,  1.54160517, -0.25187914, -0.84243574],
#        [ 0.18451869,  0.9370822 ,  0.73100034,  1.36155613],
#        [-0.32623806,  0.05567601,  0.22239961, -1.443217  ],
#        [-0.75635231,  0.81645401,  0.75044476, -0.45594693]])

# %%
np.array(df).round(6)
# Out:
# array([[-1.749765,  0.34268 ,  1.153036, -0.252436],
#        [ 0.981321,  0.514219,  0.22118 , -1.070043],
#        [-0.189496,  0.255001, -0.458027,  0.435163],
#        [-0.583595,  0.816847,  0.672721, -0.104411],
#        [-0.53128 ,  1.029733, -0.438136, -1.118318],
#        [ 1.618982,  1.541605, -0.251879, -0.842436],
#        [ 0.184519,  0.937082,  0.731   ,  1.361556],
#        [-0.326238,  0.055676,  0.2224  , -1.443217],
#        [-0.756352,  0.816454,  0.750445, -0.455947]])

# %% [markdown]
# ### 기초적인 분석

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 9 entries, 2024-09-30 to 2025-05-31
# Freq: ME
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   No1     9 non-null      float64
#  1   No2     9 non-null      float64
#  2   No3     9 non-null      float64
#  3   No4     9 non-null      float64
# dtypes: float64(4)
# memory usage: 360.0 bytes

# %%
df.describe()
# Out:
#             No1       No2       No3       No4
# count  9.000000  9.000000  9.000000  9.000000
# mean  -0.150212  0.701033  0.289193 -0.387788
# std    0.988306  0.457685  0.579920  0.877532
# min   -1.749765  0.055676 -0.458027 -1.443217
# 25%   -0.583595  0.342680 -0.251879 -1.070043
# 50%   -0.326238  0.816454  0.222400 -0.455947
# 75%    0.184519  0.937082  0.731000 -0.104411
# max    1.618982  1.541605  1.153036  1.361556

# %%
df.sum()
# Out:
# No1   -1.351906
# No2    6.309298
# No3    2.602739
# No4   -3.490089
# dtype: float64

# %%
df.mean()
# Out:
# No1   -0.150212
# No2    0.701033
# No3    0.289193
# No4   -0.387788
# dtype: float64

# %%
df.mean(axis=0)  # 열 기준 평균
# Out:
# No1   -0.150212
# No2    0.701033
# No3    0.289193
# No4   -0.387788
# dtype: float64

# %%
df.mean(axis=1)  # 행 기준 평균
# Out:
# 2024-09-30   -0.126621
# 2024-10-31    0.161669
# 2024-11-30    0.010661
# 2024-12-31    0.200390
# 2025-01-31   -0.264500
# 2025-02-28    0.516568
# 2025-03-31    0.803539
# 2025-04-30   -0.372845
# 2025-05-31    0.088650
# Freq: ME, dtype: float64

# %%
df.cumsum()   # 누적 합계
# Out:
#                  No1       No2       No3       No4
# 2024-09-30 -1.749765  0.342680  1.153036 -0.252436
# 2024-10-31 -0.768445  0.856899  1.374215 -1.322479
# 2024-11-30 -0.957941  1.111901  0.916188 -0.887316
# 2024-12-31 -1.541536  1.928748  1.588909 -0.991727
# 2025-01-31 -2.072816  2.958480  1.150774 -2.110045
# 2025-02-28 -0.453834  4.500086  0.898895 -2.952481
# 2025-03-31 -0.269316  5.437168  1.629895 -1.590925
# 2025-04-30 -0.595554  5.492844  1.852294 -3.034142
# 2025-05-31 -1.351906  6.309298  2.602739 -3.490089

# %%
np.log(df)   # log의 (  )안은 양수가 들어가야 함, warning 발생
# Out:
# /usr/local/lib/python3.11/dist-packages/pandas/core/internals/blocks.py:393: RuntimeWarning: invalid value encountered in log
#   result = func(self.values, **kwargs)
#                  No1       No2       No3       No4
# 2024-09-30       NaN -1.070957  0.142398       NaN
# 2024-10-31 -0.018856 -0.665106 -1.508780       NaN
# 2024-11-30       NaN -1.366486       NaN -0.832033
# 2024-12-31       NaN -0.202303 -0.396425       NaN
# 2025-01-31       NaN  0.029299       NaN       NaN
# 2025-02-28  0.481797  0.432824       NaN       NaN
# 2025-03-31 -1.690005 -0.064984 -0.313341  0.308628
# 2025-04-30       NaN -2.888206 -1.503279       NaN
# 2025-05-31       NaN -0.202785 -0.287089       NaN

# %%
np.sqrt(abs(df))   # 절대값으로 변경 후 루트 값을 계산함
# Out:
#                  No1       No2       No3       No4
# 2024-09-30  1.322787  0.585389  1.073795  0.502430
# 2024-10-31  0.990616  0.717091  0.470297  1.034429
# 2024-11-30  0.435311  0.504977  0.676777  0.659669
# 2024-12-31  0.763934  0.903796  0.820196  0.323127
# 2025-01-31  0.728890  1.014757  0.661918  1.057506
# 2025-02-28  1.272392  1.241614  0.501876  0.917843
# 2025-03-31  0.429556  0.968030  0.854986  1.166857
# 2025-04-30  0.571173  0.235958  0.471593  1.201340
# 2025-05-31  0.869685  0.903578  0.866282  0.675238

# %%
100 * df + 100
# Out:
#                    No1         No2         No3         No4
# 2024-09-30  -74.976547  134.268040  215.303580   74.756396
# 2024-10-31  198.132079  151.421884  122.117967   -7.004333
# 2024-11-30   81.050417  125.500144   54.197301  143.516349
# 2024-12-31   41.640495  181.684707  167.272081   89.558886
# 2025-01-31   46.871962  202.973269   56.186438  -11.831825
# 2025-02-28  261.898166  254.160517   74.812086   15.756426
# 2025-03-31  118.451869  193.708220  173.100034  236.155613
# 2025-04-30   67.376194  105.567601  122.239961  -44.321700
# 2025-05-31   24.364769  181.645401  175.044476   54.405307

# %% [markdown]
# ### 기초적인 시각화

# %%
from pylab import plt, mpl
plt.style.use('seaborn-v0_8')
mpl.rcParams['font.family'] = 'serif'
# %matplotlib inline

# %%
df.cumsum().plot(lw=2.0, figsize=(10, 6));

# %%
df.plot.bar(figsize=(10, 6), rot=30);

# %% [markdown]
# ### Series Class

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
S = pd.Series(np.linspace(0, 15, 7), name='series')
S
# Out:
# 0     0.0
# 1     2.5
# 2     5.0
# 3     7.5
# 4    10.0
# 5    12.5
# 6    15.0
# Name: series, dtype: float64

# %%
type(S)
# Out:
# pandas.core.series.Series

# %%
s = df['No1']
s
# Out:
# 2024-09-30   -1.749765
# 2024-10-31    0.981321
# 2024-11-30   -0.189496
# 2024-12-31   -0.583595
# 2025-01-31   -0.531280
# 2025-02-28    1.618982
# 2025-03-31    0.184519
# 2025-04-30   -0.326238
# 2025-05-31   -0.756352
# Freq: ME, Name: No1, dtype: float64

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
s.mean()
# Out:
# np.float64(-0.15021177307319458)

# %%
s.plot(lw=2.0, figsize=(10, 6));

# %% [markdown]
# ### GroupBy 연산

# %%
df['Quarter'] = ['Q3', 'Q4', 'Q4', 'Q4', 'Q1',
                 'Q1', 'Q1', 'Q2', 'Q2']
df
# Out:
#                  No1       No2       No3       No4 Quarter
# 2024-09-30 -1.749765  0.342680  1.153036 -0.252436      Q3
# 2024-10-31  0.981321  0.514219  0.221180 -1.070043      Q4
# 2024-11-30 -0.189496  0.255001 -0.458027  0.435163      Q4
# 2024-12-31 -0.583595  0.816847  0.672721 -0.104411      Q4
# 2025-01-31 -0.531280  1.029733 -0.438136 -1.118318      Q1
# 2025-02-28  1.618982  1.541605 -0.251879 -0.842436      Q1
# 2025-03-31  0.184519  0.937082  0.731000  1.361556      Q1
# 2025-04-30 -0.326238  0.055676  0.222400 -1.443217      Q2
# 2025-05-31 -0.756352  0.816454  0.750445 -0.455947      Q2

# %%
groups = df.groupby('Quarter')

# %%
groups.size()
# Out:
# Quarter
# Q1    3
# Q2    2
# Q3    1
# Q4    3
# dtype: int64

# %%
groups.mean()
# Out:
#               No1       No2       No3       No4
# Quarter
# Q1       0.424073  1.169473  0.013662 -0.199733
# Q2      -0.541295  0.436065  0.486422 -0.949582
# Q3      -1.749765  0.342680  1.153036 -0.252436
# Q4       0.069410  0.528689  0.145291 -0.246430

# %%
groups.max()
# Out:
#               No1       No2       No3       No4
# Quarter
# Q1       1.618982  1.541605  0.731000  1.361556
# Q2      -0.326238  0.816454  0.750445 -0.455947
# Q3      -1.749765  0.342680  1.153036 -0.252436
# Q4       0.981321  0.816847  0.672721  0.435163

# %%
groups.aggregate([min, max]).round(2)
# Out:
# /tmp/ipython-input-52-2168091236.py:1: FutureWarning: The provided callable <built-in function min> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   groups.aggregate([min, max]).round(2)
# /tmp/ipython-input-52-2168091236.py:1: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   groups.aggregate([min, max]).round(2)
#           No1         No2         No3         No4
#           min   max   min   max   min   max   min   max
# Quarter
# Q1      -0.53  1.62  0.94  1.54 -0.44  0.73 -1.12  1.36
# Q2      -0.76 -0.33  0.06  0.82  0.22  0.75 -1.44 -0.46
# Q3      -1.75 -1.75  0.34  0.34  1.15  1.15 -0.25 -0.25
# Q4      -0.58  0.98  0.26  0.82 -0.46  0.67 -1.07  0.44

# %%
df['Odd_Even'] = ['Odd', 'Even', 'Odd', 'Even', 'Odd', 'Even',
                  'Odd', 'Even', 'Odd']

# %%
groups = df.groupby(['Quarter', 'Odd_Even'])

# %%
groups.size()
# Out:
# Quarter  Odd_Even
# Q1       Even        1
#          Odd         2
# Q2       Even        1
#          Odd         1
# Q3       Odd         1
# Q4       Even        2
#          Odd         1
# dtype: int64

# %%
groups[['No1', 'No4']].aggregate([sum, np.mean])
# Out:
# /tmp/ipython-input-56-2313223015.py:1: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   groups[['No1', 'No4']].aggregate([sum, np.mean])
# /tmp/ipython-input-56-2313223015.py:1: FutureWarning: The provided callable <function mean at 0x7dea489320c0> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   groups[['No1', 'No4']].aggregate([sum, np.mean])
#                        No1                 No4
#                        sum      mean       sum      mean
# Quarter Odd_Even
# Q1      Even      1.618982  1.618982 -0.842436 -0.842436
#         Odd      -0.346762 -0.173381  0.243238  0.121619
# Q2      Even     -0.326238 -0.326238 -1.443217 -1.443217
# ...

# %% [markdown]
# ### Concatenation, Joining and Merging

# %%
df1 = pd.DataFrame(['100', '200', '300', '400'],
                    index=['a', 'b', 'c', 'd'],
                    columns=['A',])
df1
# Out:
#      A
# a  100
# b  200
# c  300
# d  400

# %%
df2 = pd.DataFrame(['200', '150', '50'],
                    index=['f', 'b', 'd'],
                    columns=['B',])
df2
# Out:
#      B
# f  200
# b  150
# d   50

# %%
pd.concat((df1, df2), sort=False)
# Out:
#      A    B
# a  100  NaN
# b  200  NaN
# c  300  NaN
# d  400  NaN
# f  NaN  200
# b  NaN  150
# d  NaN   50

# %%
pd.concat((df1, df2), ignore_index=True, sort=False)
# Out:
#      A    B
# 0  100  NaN
# 1  200  NaN
# 2  300  NaN
# 3  400  NaN
# 4  NaN  200
# 5  NaN  150
# 6  NaN   50

# %%
df1.join(df2)
# Out:
#      A    B
# a  100  NaN
# b  200  150
# c  300  NaN
# d  400   50

# %%
df2.join(df1)
# Out:
#      B    A
# f  200  NaN
# b  150  200
# d   50  400

# %%
df1.join(df2, how='left')
# Out:
#      A    B
# a  100  NaN
# b  200  150
# c  300  NaN
# d  400   50

# %%
df1.join(df2, how='right')
# Out:
#      A    B
# f  NaN  200
# b  200  150
# d  400   50

# %%
df1.join(df2, how='outer')
# Out:
#      A    B
# a  100  NaN
# b  200  150
# c  300  NaN
# d  400   50
# f  NaN  200

# %%
df1.join(df2, how='inner')
# Out:
#      A    B
# b  200  150
# d  400   50

# %%
df = pd.DataFrame()

# %%
df['A'] = df1['A']
df
# Out:
#      A
# a  100
# b  200
# c  300
# d  400

# %%
df = pd.DataFrame({'A': df1['A'], 'B': df2['B']})
df
# Out:
#      A    B
# a  100  NaN
# b  200  150
# c  300  NaN
# d  400   50
# f  NaN  200

# %%
c = pd.Series([250, 150, 50], index=['b', 'd', 'c'])
df1['C'] = c
df2['C'] = c

# %%
df1
# Out:
#      A      C
# a  100    NaN
# b  200  250.0
# c  300   50.0
# d  400  150.0

# %%
df2
# Out:
#      B      C
# f  200    NaN
# b  150  250.0
# d   50  150.0

# %%
pd.merge(df1, df2)
# Out:
#      A      C    B
# 0  100    NaN  200
# 1  200  250.0  150
# 2  400  150.0   50

# %%
pd.merge(df1, df2, on='C')
# Out:
#      A      C    B
# 0  100    NaN  200
# 1  200  250.0  150
# 2  400  150.0   50

# %%
pd.merge(df1, df2, how='outer')
# Out:
#      A      C    B
# 0  300   50.0  NaN
# 1  400  150.0   50
# 2  200  250.0  150
# 3  100    NaN  200

# %%
pd.merge(df1, df2, how='inner')
# Out:
#      A      C    B
# 0  100    NaN  200
# 1  200  250.0  150
# 2  400  150.0   50
